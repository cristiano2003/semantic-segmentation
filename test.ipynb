# %%
from src.neopolyp.dataset.coco_utils import *

train, val = infer_build("val")

sample_1, sample_2, sample_3, sample_4 = train[0], val[0], train[1], val[1]
mask1, mask2, mask3, mask4 = sample_1[1], sample_2[1], sample_3[0], sample_3[1]
# Out:
# loading annotations into memory...
# Done (t=0.78s)
# creating index...
# index created!

# %%
import matplotlib.pyplot as plt
import numpy as np


# Display the RGB image
plt.subplot(2, 2, 1)
plt.imshow(np.array(mask1))
plt.title('mask 1')
plt.axis('off')

# Display the mask
plt.subplot(2, 2, 2)
plt.imshow(np.array(mask2))  # You can choose a different colormap
plt.title('Mask 2')
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.array(mask3))  # You can choose a different colormap
plt.title('Mask 3')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(np.array(mask4))  # You can choose a different colormap
plt.title('Mask 4')
plt.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/mx/dzj5c3fj27jgyr6sj92cd1_40000gn/T/ipykernel_46407/1845316808.py in <module>
#      16
#      17 plt.subplot(2, 2, 3)
# ---> 18 plt.imshow(np.array(mask3))  # You can choose a different colormap
#      19 plt.title('Mask 3')
#      20 plt.axis('off')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
sample = dataset[1]
# Assuming you have the dataset and sample as defined in the previous example
image, mask = sample[0], sample[1]
image = torch.permute(image, (1, 2, 0))
# Display the RGB image
plt.subplot(1, 2, 1)
plt.imshow(np.array(image))
plt.title('RGB Image')
plt.axis('off')

# Display the mask
plt.subplot(1, 2, 2)
plt.imshow(np.array(mask), cmap='jet')  # You can choose a different colormap
plt.title('Mask')
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt
import numpy as np
sample = dataset[10]
# Assuming you have the dataset and sample as defined in the previous example
image, mask = sample[0], sample[1]
image = torch.permute(image, (1, 2, 0))
# Display the RGB image
plt.subplot(1, 2, 1)
plt.imshow(np.array(image))
plt.title('RGB Image')
plt.axis('off')

# Display the mask
plt.subplot(1, 2, 2)
plt.imshow(np.array(mask), cmap='jet')  # You can choose a different colormap
plt.title('Mask')
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
