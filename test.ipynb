# %%
from src.neopolyp.dataset.coco_utils import *
import matplotlib.pyplot as plt
import numpy as np

train, val = infer_build()

    
image, mask = train[0]
image, mask = np.array(torch.permute(image, (1, 2, 0))), np.array(mask)

plt.subplot(1, 2 , 1)
plt.imshow(np.array(image)) 
plt.title('Mask')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(np.array(mask))  # You can choose a different colormap
        
plt.show()
# Out:
# loading annotations into memory...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Done (t=0.77s)
# creating index...
# index created!
